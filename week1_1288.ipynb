# %% [markdown]
# <a href="https://colab.research.google.com/github/Asrithakodam/Asrithakodam/blob/main/week1_1288.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1: Explore a DataFrame
#
# ## Instructions:
# 1. Find and download a dataset of your choice (e.g., from Kaggle, UCI Repository, or Google Datasets).
# 2. Perform the following tasks:
#    - Load the dataset into a Pandas DataFrame.
#    - Display the first 5 rows and the last 5 rows of the dataset.
#    - List all column names and their data types.
#    - Count the total number of rows and columns.
#    - Calculate basic statistics (mean, median, standard deviation) for numerical columns.
# 3. Answer the following questions in Markdown cells:
#    - What does the dataset represent?
#    - Are there any missing values? If yes, mention which columns have missing data.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Task 1: Load the Dataset
# Use Pandas to load your dataset into a DataFrame.

# %%
# Import Pandas
import pandas as pd

# Load the dataset (replace 'your_dataset.csv' with your actual file path or URL)
file_path = '/content/drive/MyDrive/ydataset.csv' # Changed path to reflect user's intention and include the drive mount
#df = pd.read_csv('/Table6.xls') #original line
df = pd.read_excel('/Table6.xls')#read excel file using the file path

# Display the first few rows to confirm the dataset loaded correctly
df.head()
# Out:
#                                              <b></b> <b>HMPV N = 133</b>  \
# 0                                          Sex: male          77 (57.9%)
# 1  Age ± SD (months)<sup><a href="http://www.plos...           14.3±20.8
# 2                                        Fever ≥ 38°           90(67.7%)
# 3                                         Maximum Tª            38.8±0.6
# 4  Days of fever<sup><a href="http://www.plosone....           2.6 ± 1.6
#
#   <b>ADENOVIRUS N = 335</b> <b>P</b>  <b>OR (IC 95%)</b>
# 0                190(56.7%)    0.992  0.999(0.732–1.361)
# 1                 27.6±24.4   <0.001                 NaN
# 2                221(66.6%)    0.984  1.003(0.725–1.389)
# 3                  38.7±0.7    0.733                 NaN
# 4                   3.6±2.8    0.001                 NaN

# %% [markdown]
# ## Task 2: Display the First and Last 5 Rows
# Show the first and last 5 rows of the dataset.

# %%
# First 5 rows
df.head()

# Last 5 rows
df.tail()
# Out:
#                  <b></b> <b>HMPV N = 133</b> <b>ADENOVIRUS N = 335</b>  \
# 16             Pneumonia            9 (8.4%)                 55(16.5%)
# 17            Laryngitis            1 (0.9%)                  12(7.8%)
# 18           Prematurity          20 (15.2%)                 34(10.2%)
# 19  Antibiotic treatment          34 (25.6%)                  111(33%)
# 20         ICU admission            4 (2.2%)                  2 (1.2%)
#
#    <b>P</b>  <b>OR (IC 95%)</b>
# 16      NaN                 NaN
# 17      NaN                 NaN
# 18     0.06  1.489(1.011–2.193)
# 19    0.134  0.765(0.535–1.094)
# 20    0.335                 NaN

# %% [markdown]
# ## Task 3: List Column Names and Data Types
# List all column names and their respective data types.

# %%
# Column names and data types
df.dtypes
# Out:
# <b></b>                      object
# <b>HMPV N = 133</b>          object
# <b>ADENOVIRUS N = 335</b>    object
# <b>P</b>                     object
# <b>OR (IC 95%)</b>           object
# dtype: object

# %% [markdown]
# ## Task 4: Count Rows and Columns
# Find the total number of rows and columns in the dataset.

# %%
# Number of rows and columns
df.shape
# Out:
# (21, 5)

# %% [markdown]
# ## Task 5: Calculate Basic Statistics
# Compute the mean, median, and standard deviation for numerical columns.

# %%
# Basic statistics
df.describe()
# Out:
#           <b></b> <b>HMPV N = 133</b> <b>ADENOVIRUS N = 335</b> <b>P</b>  \
# count          21                  19                        19       15
# unique         21                  19                        19       13
# top     Sex: male          77 (57.9%)                190(56.7%)   <0.001
# freq            1                   1                         1        2
#
#         <b>OR (IC 95%)</b>
# count                    6
# unique                   6
# top     0.999(0.732–1.361)
# freq                     1

# %% [markdown]
# ## Questions:
# - What does the dataset represent? (Write your answer here as a Markdown cell.)
# - Are there any missing values? If yes, mention which columns have missing data.

# %% [markdown]
# # write down here

# %% [markdown]
# Human metapneumovirus (hMPV) is a common respiratory virus that causes an upper respiratory infection (like a cold). It is a seasonal disease that usually occurs in the winter and early spring, similar to RSV and the flu.
